# %% [markdown]
# En esta actividad, vamos a poner en práctica todo lo que aprendimos sobre procesamiento de imágenes para crear un proyecto.
#
# Objetivo: El objetivo de este proyecto es que utilicen procedimientos básicos de procesamiento de imágenes para leer una imagen, aplicarle mejoras, segmentar objetos y mostrar los resultados en una presentación visual.
#
# Duración: Tenemos 1 hora para completar este desafío.
#
# ##Preparación:
#
# Entorno: Vamos a usar Google Colab, que ya tiene todo lo que necesitamos instalado.
#
# ##Imágenes:
#
# Les voy a proporcionar un conjunto de imágenes de ejemplo para que elijan la que más les guste. Hay de todo un poco: paisajes, objetos, retratos... ¡para que tengan variedad!
#
# Si prefieren, ¡pueden usar sus propias fotos! Solo recuerden elegir una imagen con buena iluminación y calidad para que los resultados sean los mejores.
#
# Google Colab: Este cuaderno ya está listo para que trabajen. Solo tienen que seguir las instrucciones y completar el código en los espacios indicados.
#
# Pasos a seguir:
#
# ##1. ¡Empecemos importando las bibliotecas!
# Lo primero que vamos a hacer es importar las herramientas que vamos a utilizar.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 2. Leyendo y viendo nuestra imagen
# Subir la imagen: Si van a usar una foto propia, súbanla a Google Colab. Para hacerlo, hagan clic en el ícono de la carpeta en la barra lateral izquierda, luego en el ícono de "Subir" y seleccionen su archivo.
#
# Leer la imagen: Con cv2.imread(), vamos a leer la imagen que eligieron. Recuerden que OpenCV lee las imágenes en formato BGR, así que la vamos a convertir a RGB para poder verla bien con Matplotlib.
#
# Mostrar la imagen original: Usaremos matplotlib.pyplot para ver la imagen tal como es al principio.

# %%
# Descarga y lectura de imagen
# !wget -O spiderman.jpg "https://admin.sportshackster.com/WallPaperMedia/PlayerWallPaperImage/Spiderman-23_63865103589805.5.jpg" -q

# %%
# # Convierte BGR a RGB
imagen_bgr = cv2.imread('spiderman.jpg')
imagen_rgb = cv2.cvtColor(imagen_bgr, cv2.COLOR_BGR2RGB)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Mostrar imagen BGR (mal interpretada por matplotlib)
im1 = ax1.imshow(imagen_bgr)
ax1.set_title('Imagen BGR mostrada como RGB\n(Colores Incorrectos)')
plt.colorbar(im1, ax=ax1, fraction=0.046, pad=0.04)

# Mostrar imagen convertida a RGB (correctamente)
im2 = ax2.imshow(imagen_rgb)
ax2.set_title('Imagen convertida a RGB\n(Colores Correctos)')
plt.colorbar(im2, ax=ax2, fraction=0.046, pad=0.04)

plt.tight_layout() # Acomoda los elementos para que no superpongan
plt.show()

# %% [markdown]
# ##3. ¡Mejorando nuestra imagen!
# Ahora vamos a aplicar un par de técnicas para que nuestra imagen se vea aún mejor:
#
# Ajuste de brillo y contraste: Vamos a crear una función para modificar estos aspectos de la imagen.
#
# Ecualización de histograma: Con cv2.equalizeHist(), vamos a mejorar el contraste de la imagen.

# %%
def imhist3(X):
    (N, M, P) = X.shape  # Obtener dimensiones de la imagen
    n = 256  # Número de niveles de colores
    for p in range(3):  # Para cada canal de color
        h = np.zeros((256,))  # Crear un histograma vacío
        for i in range(N):  # Recorrer cada fila
            for j in range(M):  # Recorrer cada columna
                x = X[i, j, p]  # Obtener el valor del píxel
                h[x] += 1  # Incrementar el conteo en el histograma
        plt.figure(figsize=(30, 9))  # Tamaño de la figura
        plt.bar(range(n), h[0:n])  # Mostrar el histograma
        plt.title('Histograma del Canal ' + str(p))  # Título
        plt.show()  # Mostrar figura

# %%
imhist3(imagen_bgr)  # Calcular y mostrar el histograma

# %%
K = imagen_bgr.copy()  # Hacer una copia de la imagen original
Khsv = cv2.cvtColor(K, cv2.COLOR_BGR2HSV)  # Convertir a HSV
Khsv[:, :, 2] = cv2.equalizeHist(Khsv[:, :, 2])  # Ecualizar el canal de brillo (V)
Knew = cv2.cvtColor(Khsv, cv2.COLOR_HSV2BGR)  # Convertir de nuevo a BGR

# %%
plt.figure(figsize=(6, 9))  # Tamaño de la figura
plt.imshow(cv2.cvtColor(Knew, cv2.COLOR_BGR2RGB))  # Mostrar la imagen ecualizada
plt.title('Imagen Ecualizada (solo canal V)')  # Título
plt.show()  # Mostrar figura

# %% [markdown]
# ##4. ¡A segmentar por color!
# Ahora viene una parte muy interesante: vamos a separar objetos de la imagen por su color.
#
# Convertir a HSV: Vamos a pasar la imagen de RGB a HSV (Hue, Saturation, Value) porque es más fácil definir rangos de color en HSV.
#
# Definir el rango de color: Vamos a establecer los límites inferior y superior del color que queremos segmentar. En el ejemplo, segmentamos el color rojo de las flores. ¡Presten mucha atención acá! Van a tener que ajustar estos valores para su propia imagen.
#
# Crear una máscara: Con cv2.inRange(), vamos a crear una máscara que nos indique qué píxeles están dentro del rango de color y cuáles no.
#
# Aplicar la máscara: Usaremos cv2.bitwise_and() para quedarnos solo con la parte de la imagen que corresponde al color que elegimos.

# %%
# Convertir a HSV
imagen_hsv = cv2.cvtColor(imagen_rgb, cv2.COLOR_RGB2HSV)

# %%
# Segmentación básica por color utilizando HSV
# Definir el rango de color a segmentar (ejemplo: rojo)
limite_inferior_rojo = np.array([165, 100, 70])
limite_superior_rojo = np.array([180, 255, 255])

# %%
# Crear una máscara para el color rojo
mascara_roja = cv2.inRange(imagen_hsv, limite_inferior_rojo, limite_superior_rojo)

# %%
# Aplicar la máscara a la imagen original
resultado_rojo = cv2.bitwise_and(imagen_rgb, imagen_rgb, mask=mascara_roja)

# %%
# Mostrar el resultado
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(imagen_rgb)
plt.title('Original')
plt.subplot(1, 2, 2)
plt.imshow(resultado_rojo)
plt.title('Segmentación de Rojo')
plt.show()

# %%
# Definir rangos de rojo
rojo_bajo = np.array([0, 120, 70])
rojo_alto = np.array([10, 255, 255])
rojo_bajo2 = np.array([170, 120, 70])
rojo_alto2 = np.array([180, 255, 255])

# Crear máscara para ambos rangos
mascara1 = cv2.inRange(imagen_hsv, rojo_bajo, rojo_alto)
mascara2 = cv2.inRange(imagen_hsv, rojo_bajo2, rojo_alto2)

# Combinar máscaras
mascara_roja = cv2.bitwise_or(mascara1, mascara2)

# Aplicar la máscara a la imagen original para obtener la segmentación en color
imagen_segmentada = cv2.bitwise_and(imagen_rgb, imagen_rgb, mask=mascara_roja)

# Mostrar la imagen original y la segmentación en color juntas
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(imagen_rgb)
plt.title('Imagen Original')

plt.subplot(1, 2, 2)
plt.imshow(imagen_segmentada)  # Mostrar la segmentación en color
plt.title('Segmentación en Color')

plt.show()

# %% [markdown]
# ##5. ¡Dibujando y escribiendo sobre la imagen!
# Para terminar, vamos a agregarle un poco de información a nuestra imagen segmentada.
#
# Dibujar rectángulos: Con cv2.findContours() vamos a encontrar los contornos de los objetos que segmentamos, y con cv2.boundingRect() vamos a obtener las coordenadas para dibujar un rectángulo alrededor de ellos. Usaremos cv2.rectangle() para dibujar el rectángulo.
#
# Agregar texto: Con cv2.putText(), vamos a agregar un texto que describa los objetos que segmentamos.

# %%
# Encontrar contornos en la máscara
contornos, _ = cv2.findContours(mascara_roja, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Copiar imagen original para dibujar
imagen_rect = imagen_rgb.copy()

# Iterar sobre los contornos encontrados
for i, contorno in enumerate(contornos):
    x, y, w, h = cv2.boundingRect(contorno)
    cv2.rectangle(imagen_rect, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # Imprimir coordenadas del rectángulo
    print(f"Objeto {i+1}:")
    print(f"  Coordenadas esquina superior izquierda (x, y): ({x}, {y})")
    print(f"  Ancho: {w}, Alto: {h}")
    print(f"  Esquina inferior derecha (x, y): ({x + w}, {y + h})\n")
# Out:
# Objeto 1:
#   Coordenadas esquina superior izquierda (x, y): (766, 3809)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (767, 3810)
#
# Objeto 2:
#   Coordenadas esquina superior izquierda (x, y): (782, 3745)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (783, 3746)
#
# Objeto 3:
#   Coordenadas esquina superior izquierda (x, y): (715, 3573)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (716, 3574)
#
# Objeto 4:
#   Coordenadas esquina superior izquierda (x, y): (712, 3571)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (714, 3573)
#
# Objeto 5:
#   Coordenadas esquina superior izquierda (x, y): (132, 3520)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (133, 3521)
#
# Objeto 6:
#   Coordenadas esquina superior izquierda (x, y): (163, 3515)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (164, 3516)
#
# Objeto 7:
#   Coordenadas esquina superior izquierda (x, y): (133, 3514)
#   Ancho: 5, Alto: 8
#   Esquina inferior derecha (x, y): (138, 3522)
#
# Objeto 8:
#   Coordenadas esquina superior izquierda (x, y): (555, 3501)
#   Ancho: 4, Alto: 3
#   Esquina inferior derecha (x, y): (559, 3504)
#
# Objeto 9:
#   Coordenadas esquina superior izquierda (x, y): (538, 3491)
#   Ancho: 5, Alto: 4
#   Esquina inferior derecha (x, y): (543, 3495)
#
# Objeto 10:
#   Coordenadas esquina superior izquierda (x, y): (577, 3485)
#   Ancho: 3, Alto: 2
#   Esquina inferior derecha (x, y): (580, 3487)
#
# Objeto 11:
#   Coordenadas esquina superior izquierda (x, y): (304, 3478)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (305, 3480)
#
# Objeto 12:
#   Coordenadas esquina superior izquierda (x, y): (127, 3476)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (128, 3477)
#
# Objeto 13:
#   Coordenadas esquina superior izquierda (x, y): (304, 3473)
#   Ancho: 3, Alto: 3
#   Esquina inferior derecha (x, y): (307, 3476)
#
# Objeto 14:
#   Coordenadas esquina superior izquierda (x, y): (132, 3470)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (133, 3471)
#
# Objeto 15:
#   Coordenadas esquina superior izquierda (x, y): (568, 3468)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (569, 3469)
#
# Objeto 16:
#   Coordenadas esquina superior izquierda (x, y): (305, 3468)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (306, 3469)
#
# Objeto 17:
#   Coordenadas esquina superior izquierda (x, y): (564, 3465)
#   Ancho: 2, Alto: 3
#   Esquina inferior derecha (x, y): (566, 3468)
#
# Objeto 18:
#   Coordenadas esquina superior izquierda (x, y): (566, 3462)
#   Ancho: 4, Alto: 3
#   Esquina inferior derecha (x, y): (570, 3465)
#
# Objeto 19:
#   Coordenadas esquina superior izquierda (x, y): (542, 3458)
#   Ancho: 2, Alto: 3
#   Esquina inferior derecha (x, y): (544, 3461)
#
# Objeto 20:
#   Coordenadas esquina superior izquierda (x, y): (256, 3456)
#   Ancho: 3, Alto: 3
#   Esquina inferior derecha (x, y): (259, 3459)
#
# Objeto 21:
#   Coordenadas esquina superior izquierda (x, y): (303, 3454)
#   Ancho: 3, Alto: 6
#   Esquina inferior derecha (x, y): (306, 3460)
#
# Objeto 22:
#   Coordenadas esquina superior izquierda (x, y): (606, 3453)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (608, 3455)
#
# Objeto 23:
#   Coordenadas esquina superior izquierda (x, y): (152, 3440)
#   Ancho: 4, Alto: 5
#   Esquina inferior derecha (x, y): (156, 3445)
#
# Objeto 24:
#   Coordenadas esquina superior izquierda (x, y): (393, 3433)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (394, 3434)
#
# Objeto 25:
#   Coordenadas esquina superior izquierda (x, y): (384, 3432)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (386, 3434)
#
# Objeto 26:
#   Coordenadas esquina superior izquierda (x, y): (46, 3432)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (47, 3433)
#
# Objeto 27:
#   Coordenadas esquina superior izquierda (x, y): (387, 3429)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (388, 3430)
#
# Objeto 28:
#   Coordenadas esquina superior izquierda (x, y): (162, 3428)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (163, 3430)
#
# Objeto 29:
#   Coordenadas esquina superior izquierda (x, y): (304, 3427)
#   Ancho: 2, Alto: 3
#   Esquina inferior derecha (x, y): (306, 3430)
#
# Objeto 30:
#   Coordenadas esquina superior izquierda (x, y): (390, 3425)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (391, 3426)
#
# Objeto 31:
#   Coordenadas esquina superior izquierda (x, y): (560, 3412)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (561, 3413)
#
# Objeto 32:
#   Coordenadas esquina superior izquierda (x, y): (208, 3408)
#   Ancho: 5, Alto: 7
#   Esquina inferior derecha (x, y): (213, 3415)
#
# Objeto 33:
#   Coordenadas esquina superior izquierda (x, y): (304, 3401)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (305, 3402)
#
# Objeto 34:
#   Coordenadas esquina superior izquierda (x, y): (183, 3400)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (184, 3402)
#
# Objeto 35:
#   Coordenadas esquina superior izquierda (x, y): (144, 3400)
#   Ancho: 4, Alto: 3
#   Esquina inferior derecha (x, y): (148, 3403)
#
# Objeto 36:
#   Coordenadas esquina superior izquierda (x, y): (121, 3398)
#   Ancho: 2, Alto: 3
#   Esquina inferior derecha (x, y): (123, 3401)
#
# Objeto 37:
#   Coordenadas esquina superior izquierda (x, y): (189, 3390)
#   Ancho: 3, Alto: 3
#   Esquina inferior derecha (x, y): (192, 3393)
#
# Objeto 38:
#   Coordenadas esquina superior izquierda (x, y): (381, 3389)
#   Ancho: 4, Alto: 4
#   Esquina inferior derecha (x, y): (385, 3393)
#
# Objeto 39:
#   Coordenadas esquina superior izquierda (x, y): (113, 3382)
#   Ancho: 4, Alto: 3
#   Esquina inferior derecha (x, y): (117, 3385)
#
# Objeto 40:
#   Coordenadas esquina superior izquierda (x, y): (144, 3378)
#   Ancho: 7, Alto: 3
#   Esquina inferior derecha (x, y): (151, 3381)
#
# Objeto 41:
#   Coordenadas esquina superior izquierda (x, y): (398, 3377)
#   Ancho: 7, Alto: 6
#   Esquina inferior derecha (x, y): (405, 3383)
#
# Objeto 42:
#   Coordenadas esquina superior izquierda (x, y): (199, 3377)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (200, 3378)
#
# Objeto 43:
#   Coordenadas esquina superior izquierda (x, y): (556, 3376)
#   Ancho: 4, Alto: 7
#   Esquina inferior derecha (x, y): (560, 3383)
#
# Objeto 44:
#   Coordenadas esquina superior izquierda (x, y): (144, 3375)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (145, 3377)
#
# Objeto 45:
#   Coordenadas esquina superior izquierda (x, y): (146, 3374)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (147, 3375)
#
# Objeto 46:
#   Coordenadas esquina superior izquierda (x, y): (582, 3373)
#   Ancho: 5, Alto: 5
#   Esquina inferior derecha (x, y): (587, 3378)
#
# Objeto 47:
#   Coordenadas esquina superior izquierda (x, y): (148, 3373)
#   Ancho: 4, Alto: 4
#   Esquina inferior derecha (x, y): (152, 3377)
#
# Objeto 48:
#   Coordenadas esquina superior izquierda (x, y): (414, 3370)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (416, 3371)
#
# Objeto 49:
#   Coordenadas esquina superior izquierda (x, y): (43, 3368)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (44, 3369)
#
# Objeto 50:
#   Coordenadas esquina superior izquierda (x, y): (203, 3367)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (204, 3369)
#
# Objeto 51:
#   Coordenadas esquina superior izquierda (x, y): (664, 3359)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (665, 3360)
#
# Objeto 52:
#   Coordenadas esquina superior izquierda (x, y): (658, 3354)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (659, 3356)
#
# Objeto 53:
#   Coordenadas esquina superior izquierda (x, y): (430, 3340)
#   Ancho: 2, Alto: 3
#   Esquina inferior derecha (x, y): (432, 3343)
#
# Objeto 54:
#   Coordenadas esquina superior izquierda (x, y): (590, 3334)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (592, 3336)
#
# Objeto 55:
#   Coordenadas esquina superior izquierda (x, y): (276, 3333)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (277, 3335)
#
# Objeto 56:
#   Coordenadas esquina superior izquierda (x, y): (606, 3328)
#   Ancho: 2, Alto: 3
#   Esquina inferior derecha (x, y): (608, 3331)
#
# Objeto 57:
#   Coordenadas esquina superior izquierda (x, y): (22, 3323)
#   Ancho: 6, Alto: 9
#   Esquina inferior derecha (x, y): (28, 3332)
#
# Objeto 58:
#   Coordenadas esquina superior izquierda (x, y): (519, 3316)
#   Ancho: 4, Alto: 5
#   Esquina inferior derecha (x, y): (523, 3321)
#
# Objeto 59:
#   Coordenadas esquina superior izquierda (x, y): (232, 3314)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (234, 3315)
#
# Objeto 60:
#   Coordenadas esquina superior izquierda (x, y): (599, 3312)
#   Ancho: 3, Alto: 5
#   Esquina inferior derecha (x, y): (602, 3317)
#
# Objeto 61:
#   Coordenadas esquina superior izquierda (x, y): (148, 3292)
#   Ancho: 3, Alto: 2
#   Esquina inferior derecha (x, y): (151, 3294)
#
# Objeto 62:
#   Coordenadas esquina superior izquierda (x, y): (387, 3287)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (389, 3288)
#
# Objeto 63:
#   Coordenadas esquina superior izquierda (x, y): (45, 3285)
#   Ancho: 3, Alto: 2
#   Esquina inferior derecha (x, y): (48, 3287)
#
# Objeto 64:
#   Coordenadas esquina superior izquierda (x, y): (561, 3284)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (562, 3285)
#
# Objeto 65:
#   Coordenadas esquina superior izquierda (x, y): (386, 3283)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (387, 3284)
#
# Objeto 66:
#   Coordenadas esquina superior izquierda (x, y): (303, 3282)
#   Ancho: 4, Alto: 7
#   Esquina inferior derecha (x, y): (307, 3289)
#
# Objeto 67:
#   Coordenadas esquina superior izquierda (x, y): (383, 3281)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (384, 3283)
#
# Objeto 68:
#   Coordenadas esquina superior izquierda (x, y): (44, 3281)
#   Ancho: 2, Alto: 3
#   Esquina inferior derecha (x, y): (46, 3284)
#
# Objeto 69:
#   Coordenadas esquina superior izquierda (x, y): (305, 3280)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (306, 3281)
#
# Objeto 70:
#   Coordenadas esquina superior izquierda (x, y): (186, 3280)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (188, 3281)
#
# Objeto 71:
#   Coordenadas esquina superior izquierda (x, y): (22, 3270)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (23, 3271)
#
# Objeto 72:
#   Coordenadas esquina superior izquierda (x, y): (44, 3267)
#   Ancho: 4, Alto: 6
#   Esquina inferior derecha (x, y): (48, 3273)
#
# Objeto 73:
#   Coordenadas esquina superior izquierda (x, y): (676, 3265)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (678, 3266)
#
# Objeto 74:
#   Coordenadas esquina superior izquierda (x, y): (23, 3262)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (25, 3264)
#
# Objeto 75:
#   Coordenadas esquina superior izquierda (x, y): (573, 3256)
#   Ancho: 5, Alto: 6
#   Esquina inferior derecha (x, y): (578, 3262)
#
# Objeto 76:
#   Coordenadas esquina superior izquierda (x, y): (41, 3256)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (42, 3257)
#
# Objeto 77:
#   Coordenadas esquina superior izquierda (x, y): (154, 3255)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (155, 3256)
#
# Objeto 78:
#   Coordenadas esquina superior izquierda (x, y): (61, 3254)
#   Ancho: 3, Alto: 1
#   Esquina inferior derecha (x, y): (64, 3255)
#
# Objeto 79:
#   Coordenadas esquina superior izquierda (x, y): (584, 3253)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (586, 3255)
#
# Objeto 80:
#   Coordenadas esquina superior izquierda (x, y): (521, 3248)
#   Ancho: 2, Alto: 3
#   Esquina inferior derecha (x, y): (523, 3251)
#
# Objeto 81:
#   Coordenadas esquina superior izquierda (x, y): (206, 3247)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (207, 3248)
#
# Objeto 82:
#   Coordenadas esquina superior izquierda (x, y): (88, 3244)
#   Ancho: 4, Alto: 3
#   Esquina inferior derecha (x, y): (92, 3247)
#
# Objeto 83:
#   Coordenadas esquina superior izquierda (x, y): (44, 3239)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (45, 3240)
#
# Objeto 84:
#   Coordenadas esquina superior izquierda (x, y): (43, 3236)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (44, 3237)
#
# Objeto 85:
#   Coordenadas esquina superior izquierda (x, y): (540, 2939)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (541, 2940)
#
# Objeto 86:
#   Coordenadas esquina superior izquierda (x, y): (128, 2923)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (129, 2924)
#
# Objeto 87:
#   Coordenadas esquina superior izquierda (x, y): (131, 2921)
#   Ancho: 2, Alto: 3
#   Esquina inferior derecha (x, y): (133, 2924)
#
# Objeto 88:
#   Coordenadas esquina superior izquierda (x, y): (132, 2916)
#   Ancho: 2, Alto: 4
#   Esquina inferior derecha (x, y): (134, 2920)
#
# Objeto 89:
#   Coordenadas esquina superior izquierda (x, y): (128, 2913)
#   Ancho: 2, Alto: 4
#   Esquina inferior derecha (x, y): (130, 2917)
#
# Objeto 90:
#   Coordenadas esquina superior izquierda (x, y): (135, 2909)
#   Ancho: 5, Alto: 5
#   Esquina inferior derecha (x, y): (140, 2914)
#
# Objeto 91:
#   Coordenadas esquina superior izquierda (x, y): (527, 2902)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (528, 2903)
#
# Objeto 92:
#   Coordenadas esquina superior izquierda (x, y): (529, 2900)
#   Ancho: 1, Alto: 3
#   Esquina inferior derecha (x, y): (530, 2903)
#
# Objeto 93:
#   Coordenadas esquina superior izquierda (x, y): (530, 2899)
#   Ancho: 9, Alto: 8
#   Esquina inferior derecha (x, y): (539, 2907)
#
# Objeto 94:
#   Coordenadas esquina superior izquierda (x, y): (140, 2897)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (141, 2898)
#
# Objeto 95:
#   Coordenadas esquina superior izquierda (x, y): (894, 2895)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (896, 2896)
#
# Objeto 96:
#   Coordenadas esquina superior izquierda (x, y): (134, 2895)
#   Ancho: 2, Alto: 3
#   Esquina inferior derecha (x, y): (136, 2898)
#
# Objeto 97:
#   Coordenadas esquina superior izquierda (x, y): (547, 2894)
#   Ancho: 3, Alto: 3
#   Esquina inferior derecha (x, y): (550, 2897)
#
# Objeto 98:
#   Coordenadas esquina superior izquierda (x, y): (130, 2894)
#   Ancho: 1, Alto: 3
#   Esquina inferior derecha (x, y): (131, 2897)
#
# Objeto 99:
#   Coordenadas esquina superior izquierda (x, y): (551, 2891)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (552, 2892)
#
# Objeto 100:
#   Coordenadas esquina superior izquierda (x, y): (541, 2891)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (543, 2892)
#
# Objeto 101:
#   Coordenadas esquina superior izquierda (x, y): (128, 2891)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (129, 2892)
#
# Objeto 102:
#   Coordenadas esquina superior izquierda (x, y): (132, 2888)
#   Ancho: 3, Alto: 5
#   Esquina inferior derecha (x, y): (135, 2893)
#
# Objeto 103:
#   Coordenadas esquina superior izquierda (x, y): (524, 2887)
#   Ancho: 7, Alto: 4
#   Esquina inferior derecha (x, y): (531, 2891)
#
# Objeto 104:
#   Coordenadas esquina superior izquierda (x, y): (552, 2886)
#   Ancho: 1, Alto: 3
#   Esquina inferior derecha (x, y): (553, 2889)
#
# Objeto 105:
#   Coordenadas esquina superior izquierda (x, y): (544, 2885)
#   Ancho: 3, Alto: 4
#   Esquina inferior derecha (x, y): (547, 2889)
#
# Objeto 106:
#   Coordenadas esquina superior izquierda (x, y): (138, 2884)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (139, 2885)
#
# Objeto 107:
#   Coordenadas esquina superior izquierda (x, y): (129, 2884)
#   Ancho: 1, Alto: 4
#   Esquina inferior derecha (x, y): (130, 2888)
#
# Objeto 108:
#   Coordenadas esquina superior izquierda (x, y): (551, 2883)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (553, 2884)
#
# Objeto 109:
#   Coordenadas esquina superior izquierda (x, y): (522, 2883)
#   Ancho: 3, Alto: 5
#   Esquina inferior derecha (x, y): (525, 2888)
#
# Objeto 110:
#   Coordenadas esquina superior izquierda (x, y): (135, 2883)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (137, 2885)
#
# Objeto 111:
#   Coordenadas esquina superior izquierda (x, y): (543, 2882)
#   Ancho: 3, Alto: 2
#   Esquina inferior derecha (x, y): (546, 2884)
#
# Objeto 112:
#   Coordenadas esquina superior izquierda (x, y): (130, 2881)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (132, 2883)
#
# Objeto 113:
#   Coordenadas esquina superior izquierda (x, y): (132, 2879)
#   Ancho: 5, Alto: 3
#   Esquina inferior derecha (x, y): (137, 2882)
#
# Objeto 114:
#   Coordenadas esquina superior izquierda (x, y): (554, 2877)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (555, 2878)
#
# Objeto 115:
#   Coordenadas esquina superior izquierda (x, y): (522, 2875)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (523, 2876)
#
# Objeto 116:
#   Coordenadas esquina superior izquierda (x, y): (132, 2875)
#   Ancho: 4, Alto: 3
#   Esquina inferior derecha (x, y): (136, 2878)
#
# Objeto 117:
#   Coordenadas esquina superior izquierda (x, y): (131, 2875)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (132, 2876)
#
# Objeto 118:
#   Coordenadas esquina superior izquierda (x, y): (52, 2875)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (54, 2877)
#
# Objeto 119:
#   Coordenadas esquina superior izquierda (x, y): (1013, 2874)
#   Ancho: 3, Alto: 3
#   Esquina inferior derecha (x, y): (1016, 2877)
#
# Objeto 120:
#   Coordenadas esquina superior izquierda (x, y): (506, 2874)
#   Ancho: 2, Alto: 5
#   Esquina inferior derecha (x, y): (508, 2879)
#
# Objeto 121:
#   Coordenadas esquina superior izquierda (x, y): (526, 2873)
#   Ancho: 21, Alto: 10
#   Esquina inferior derecha (x, y): (547, 2883)
#
# Objeto 122:
#   Coordenadas esquina superior izquierda (x, y): (509, 2873)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (510, 2874)
#
# Objeto 123:
#   Coordenadas esquina superior izquierda (x, y): (140, 2873)
#   Ancho: 2, Alto: 9
#   Esquina inferior derecha (x, y): (142, 2882)
#
# Objeto 124:
#   Coordenadas esquina superior izquierda (x, y): (130, 2873)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (131, 2874)
#
# Objeto 125:
#   Coordenadas esquina superior izquierda (x, y): (137, 2872)
#   Ancho: 1, Alto: 3
#   Esquina inferior derecha (x, y): (138, 2875)
#
# Objeto 126:
#   Coordenadas esquina superior izquierda (x, y): (548, 2871)
#   Ancho: 8, Alto: 5
#   Esquina inferior derecha (x, y): (556, 2876)
#
# Objeto 127:
#   Coordenadas esquina superior izquierda (x, y): (139, 2870)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (140, 2871)
#
# Objeto 128:
#   Coordenadas esquina superior izquierda (x, y): (1037, 2868)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1038, 2869)
#
# Objeto 129:
#   Coordenadas esquina superior izquierda (x, y): (94, 2868)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (95, 2869)
#
# Objeto 130:
#   Coordenadas esquina superior izquierda (x, y): (1040, 2867)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1041, 2868)
#
# Objeto 131:
#   Coordenadas esquina superior izquierda (x, y): (552, 2867)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (553, 2869)
#
# Objeto 132:
#   Coordenadas esquina superior izquierda (x, y): (66, 2865)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (68, 2866)
#
# Objeto 133:
#   Coordenadas esquina superior izquierda (x, y): (88, 2864)
#   Ancho: 7, Alto: 3
#   Esquina inferior derecha (x, y): (95, 2867)
#
# Objeto 134:
#   Coordenadas esquina superior izquierda (x, y): (554, 2862)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (555, 2863)
#
# Objeto 135:
#   Coordenadas esquina superior izquierda (x, y): (1039, 2860)
#   Ancho: 5, Alto: 7
#   Esquina inferior derecha (x, y): (1044, 2867)
#
# Objeto 136:
#   Coordenadas esquina superior izquierda (x, y): (553, 2860)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (554, 2861)
#
# Objeto 137:
#   Coordenadas esquina superior izquierda (x, y): (544, 2860)
#   Ancho: 5, Alto: 5
#   Esquina inferior derecha (x, y): (549, 2865)
#
# Objeto 138:
#   Coordenadas esquina superior izquierda (x, y): (551, 2859)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (552, 2860)
#
# Objeto 139:
#   Coordenadas esquina superior izquierda (x, y): (131, 2859)
#   Ancho: 4, Alto: 4
#   Esquina inferior derecha (x, y): (135, 2863)
#
# Objeto 140:
#   Coordenadas esquina superior izquierda (x, y): (370, 2857)
#   Ancho: 1, Alto: 3
#   Esquina inferior derecha (x, y): (371, 2860)
#
# Objeto 141:
#   Coordenadas esquina superior izquierda (x, y): (546, 2855)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (548, 2857)
#
# Objeto 142:
#   Coordenadas esquina superior izquierda (x, y): (522, 2855)
#   Ancho: 20, Alto: 16
#   Esquina inferior derecha (x, y): (542, 2871)
#
# Objeto 143:
#   Coordenadas esquina superior izquierda (x, y): (134, 2855)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (135, 2856)
#
# Objeto 144:
#   Coordenadas esquina superior izquierda (x, y): (597, 2854)
#   Ancho: 3, Alto: 3
#   Esquina inferior derecha (x, y): (600, 2857)
#
# Objeto 145:
#   Coordenadas esquina superior izquierda (x, y): (128, 2853)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (129, 2855)
#
# Objeto 146:
#   Coordenadas esquina superior izquierda (x, y): (1035, 2852)
#   Ancho: 6, Alto: 6
#   Esquina inferior derecha (x, y): (1041, 2858)
#
# Objeto 147:
#   Coordenadas esquina superior izquierda (x, y): (546, 2852)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (547, 2854)
#
# Objeto 148:
#   Coordenadas esquina superior izquierda (x, y): (528, 2852)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (529, 2853)
#
# Objeto 149:
#   Coordenadas esquina superior izquierda (x, y): (133, 2848)
#   Ancho: 2, Alto: 4
#   Esquina inferior derecha (x, y): (135, 2852)
#
# Objeto 150:
#   Coordenadas esquina superior izquierda (x, y): (934, 2847)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (935, 2848)
#
# Objeto 151:
#   Coordenadas esquina superior izquierda (x, y): (705, 2847)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (706, 2848)
#
# Objeto 152:
#   Coordenadas esquina superior izquierda (x, y): (130, 2847)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (131, 2848)
#
# Objeto 153:
#   Coordenadas esquina superior izquierda (x, y): (531, 2846)
#   Ancho: 3, Alto: 4
#   Esquina inferior derecha (x, y): (534, 2850)
#
# Objeto 154:
#   Coordenadas esquina superior izquierda (x, y): (529, 2845)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (530, 2847)
#
# Objeto 155:
#   Coordenadas esquina superior izquierda (x, y): (1044, 2844)
#   Ancho: 5, Alto: 4
#   Esquina inferior derecha (x, y): (1049, 2848)
#
# Objeto 156:
#   Coordenadas esquina superior izquierda (x, y): (529, 2843)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (530, 2844)
#
# Objeto 157:
#   Coordenadas esquina superior izquierda (x, y): (922, 2842)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (923, 2843)
#
# Objeto 158:
#   Coordenadas esquina superior izquierda (x, y): (129, 2840)
#   Ancho: 6, Alto: 6
#   Esquina inferior derecha (x, y): (135, 2846)
#
# Objeto 159:
#   Coordenadas esquina superior izquierda (x, y): (540, 2839)
#   Ancho: 2, Alto: 3
#   Esquina inferior derecha (x, y): (542, 2842)
#
# Objeto 160:
#   Coordenadas esquina superior izquierda (x, y): (536, 2839)
#   Ancho: 3, Alto: 6
#   Esquina inferior derecha (x, y): (539, 2845)
#
# Objeto 161:
#   Coordenadas esquina superior izquierda (x, y): (1137, 2836)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (1139, 2838)
#
# Objeto 162:
#   Coordenadas esquina superior izquierda (x, y): (560, 2835)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (562, 2837)
#
# Objeto 163:
#   Coordenadas esquina superior izquierda (x, y): (528, 2834)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (529, 2835)
#
# Objeto 164:
#   Coordenadas esquina superior izquierda (x, y): (129, 2834)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (130, 2836)
#
# Objeto 165:
#   Coordenadas esquina superior izquierda (x, y): (1073, 2833)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1074, 2834)
#
# Objeto 166:
#   Coordenadas esquina superior izquierda (x, y): (669, 2833)
#   Ancho: 3, Alto: 6
#   Esquina inferior derecha (x, y): (672, 2839)
#
# Objeto 167:
#   Coordenadas esquina superior izquierda (x, y): (560, 2833)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (561, 2834)
#
# Objeto 168:
#   Coordenadas esquina superior izquierda (x, y): (132, 2832)
#   Ancho: 3, Alto: 4
#   Esquina inferior derecha (x, y): (135, 2836)
#
# Objeto 169:
#   Coordenadas esquina superior izquierda (x, y): (125, 2830)
#   Ancho: 4, Alto: 3
#   Esquina inferior derecha (x, y): (129, 2833)
#
# Objeto 170:
#   Coordenadas esquina superior izquierda (x, y): (551, 2828)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (553, 2830)
#
# Objeto 171:
#   Coordenadas esquina superior izquierda (x, y): (10, 2827)
#   Ancho: 6, Alto: 3
#   Esquina inferior derecha (x, y): (16, 2830)
#
# Objeto 172:
#   Coordenadas esquina superior izquierda (x, y): (894, 2826)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (895, 2828)
#
# Objeto 173:
#   Coordenadas esquina superior izquierda (x, y): (521, 2825)
#   Ancho: 5, Alto: 4
#   Esquina inferior derecha (x, y): (526, 2829)
#
# Objeto 174:
#   Coordenadas esquina superior izquierda (x, y): (554, 2824)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (555, 2826)
#
# Objeto 175:
#   Coordenadas esquina superior izquierda (x, y): (541, 2822)
#   Ancho: 7, Alto: 7
#   Esquina inferior derecha (x, y): (548, 2829)
#
# Objeto 176:
#   Coordenadas esquina superior izquierda (x, y): (1077, 2821)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1078, 2822)
#
# Objeto 177:
#   Coordenadas esquina superior izquierda (x, y): (547, 2818)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (548, 2820)
#
# Objeto 178:
#   Coordenadas esquina superior izquierda (x, y): (528, 2817)
#   Ancho: 2, Alto: 3
#   Esquina inferior derecha (x, y): (530, 2820)
#
# Objeto 179:
#   Coordenadas esquina superior izquierda (x, y): (131, 2814)
#   Ancho: 4, Alto: 12
#   Esquina inferior derecha (x, y): (135, 2826)
#
# Objeto 180:
#   Coordenadas esquina superior izquierda (x, y): (128, 2813)
#   Ancho: 1, Alto: 3
#   Esquina inferior derecha (x, y): (129, 2816)
#
# Objeto 181:
#   Coordenadas esquina superior izquierda (x, y): (1088, 2810)
#   Ancho: 4, Alto: 1
#   Esquina inferior derecha (x, y): (1092, 2811)
#
# Objeto 182:
#   Coordenadas esquina superior izquierda (x, y): (1010, 2810)
#   Ancho: 9, Alto: 3
#   Esquina inferior derecha (x, y): (1019, 2813)
#
# Objeto 183:
#   Coordenadas esquina superior izquierda (x, y): (546, 2810)
#   Ancho: 2, Alto: 6
#   Esquina inferior derecha (x, y): (548, 2816)
#
# Objeto 184:
#   Coordenadas esquina superior izquierda (x, y): (128, 2809)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (129, 2811)
#
# Objeto 185:
#   Coordenadas esquina superior izquierda (x, y): (568, 2808)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (570, 2810)
#
# Objeto 186:
#   Coordenadas esquina superior izquierda (x, y): (132, 2808)
#   Ancho: 3, Alto: 3
#   Esquina inferior derecha (x, y): (135, 2811)
#
# Objeto 187:
#   Coordenadas esquina superior izquierda (x, y): (70, 2807)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (71, 2808)
#
# Objeto 188:
#   Coordenadas esquina superior izquierda (x, y): (46, 2807)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (47, 2808)
#
# Objeto 189:
#   Coordenadas esquina superior izquierda (x, y): (962, 2806)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (964, 2808)
#
# Objeto 190:
#   Coordenadas esquina superior izquierda (x, y): (71, 2805)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (72, 2806)
#
# Objeto 191:
#   Coordenadas esquina superior izquierda (x, y): (355, 2804)
#   Ancho: 4, Alto: 4
#   Esquina inferior derecha (x, y): (359, 2808)
#
# Objeto 192:
#   Coordenadas esquina superior izquierda (x, y): (578, 2800)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (579, 2801)
#
# Objeto 193:
#   Coordenadas esquina superior izquierda (x, y): (526, 2797)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (528, 2798)
#
# Objeto 194:
#   Coordenadas esquina superior izquierda (x, y): (442, 2796)
#   Ancho: 4, Alto: 5
#   Esquina inferior derecha (x, y): (446, 2801)
#
# Objeto 195:
#   Coordenadas esquina superior izquierda (x, y): (545, 2795)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (546, 2796)
#
# Objeto 196:
#   Coordenadas esquina superior izquierda (x, y): (536, 2793)
#   Ancho: 5, Alto: 4
#   Esquina inferior derecha (x, y): (541, 2797)
#
# Objeto 197:
#   Coordenadas esquina superior izquierda (x, y): (530, 2793)
#   Ancho: 4, Alto: 5
#   Esquina inferior derecha (x, y): (534, 2798)
#
# Objeto 198:
#   Coordenadas esquina superior izquierda (x, y): (546, 2792)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (547, 2793)
#
# Objeto 199:
#   Coordenadas esquina superior izquierda (x, y): (259, 2792)
#   Ancho: 2, Alto: 4
#   Esquina inferior derecha (x, y): (261, 2796)
#
# Objeto 200:
#   Coordenadas esquina superior izquierda (x, y): (580, 2791)
#   Ancho: 8, Alto: 8
#   Esquina inferior derecha (x, y): (588, 2799)
#
# Objeto 201:
#   Coordenadas esquina superior izquierda (x, y): (1160, 2790)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (1162, 2791)
#
# Objeto 202:
#   Coordenadas esquina superior izquierda (x, y): (889, 2790)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (890, 2792)
#
# Objeto 203:
#   Coordenadas esquina superior izquierda (x, y): (529, 2790)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (530, 2791)
#
# Objeto 204:
#   Coordenadas esquina superior izquierda (x, y): (128, 2789)
#   Ancho: 13, Alto: 2
#   Esquina inferior derecha (x, y): (141, 2791)
#
# Objeto 205:
#   Coordenadas esquina superior izquierda (x, y): (591, 2787)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (592, 2788)
#
# Objeto 206:
#   Coordenadas esquina superior izquierda (x, y): (560, 2786)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (561, 2787)
#
# Objeto 207:
#   Coordenadas esquina superior izquierda (x, y): (413, 2785)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (414, 2786)
#
# Objeto 208:
#   Coordenadas esquina superior izquierda (x, y): (443, 2784)
#   Ancho: 6, Alto: 7
#   Esquina inferior derecha (x, y): (449, 2791)
#
# Objeto 209:
#   Coordenadas esquina superior izquierda (x, y): (920, 2783)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (921, 2784)
#
# Objeto 210:
#   Coordenadas esquina superior izquierda (x, y): (767, 2783)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (768, 2784)
#
# Objeto 211:
#   Coordenadas esquina superior izquierda (x, y): (440, 2783)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (441, 2784)
#
# Objeto 212:
#   Coordenadas esquina superior izquierda (x, y): (21, 2783)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (23, 2784)
#
# Objeto 213:
#   Coordenadas esquina superior izquierda (x, y): (1148, 2782)
#   Ancho: 4, Alto: 3
#   Esquina inferior derecha (x, y): (1152, 2785)
#
# Objeto 214:
#   Coordenadas esquina superior izquierda (x, y): (903, 2781)
#   Ancho: 16, Alto: 6
#   Esquina inferior derecha (x, y): (919, 2787)
#
# Objeto 215:
#   Coordenadas esquina superior izquierda (x, y): (528, 2781)
#   Ancho: 2, Alto: 3
#   Esquina inferior derecha (x, y): (530, 2784)
#
# Objeto 216:
#   Coordenadas esquina superior izquierda (x, y): (49, 2781)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (50, 2782)
#
# Objeto 217:
#   Coordenadas esquina superior izquierda (x, y): (768, 2780)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (769, 2782)
#
# Objeto 218:
#   Coordenadas esquina superior izquierda (x, y): (596, 2779)
#   Ancho: 3, Alto: 4
#   Esquina inferior derecha (x, y): (599, 2783)
#
# Objeto 219:
#   Coordenadas esquina superior izquierda (x, y): (545, 2779)
#   Ancho: 3, Alto: 5
#   Esquina inferior derecha (x, y): (548, 2784)
#
# Objeto 220:
#   Coordenadas esquina superior izquierda (x, y): (766, 2777)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (768, 2779)
#
# Objeto 221:
#   Coordenadas esquina superior izquierda (x, y): (109, 2776)
#   Ancho: 3, Alto: 2
#   Esquina inferior derecha (x, y): (112, 2778)
#
# Objeto 222:
#   Coordenadas esquina superior izquierda (x, y): (50, 2776)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (51, 2777)
#
# Objeto 223:
#   Coordenadas esquina superior izquierda (x, y): (1241, 2775)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (1243, 2777)
#
# Objeto 224:
#   Coordenadas esquina superior izquierda (x, y): (890, 2775)
#   Ancho: 9, Alto: 14
#   Esquina inferior derecha (x, y): (899, 2789)
#
# Objeto 225:
#   Coordenadas esquina superior izquierda (x, y): (913, 2774)
#   Ancho: 5, Alto: 3
#   Esquina inferior derecha (x, y): (918, 2777)
#
# Objeto 226:
#   Coordenadas esquina superior izquierda (x, y): (900, 2774)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (901, 2775)
#
# Objeto 227:
#   Coordenadas esquina superior izquierda (x, y): (600, 2773)
#   Ancho: 5, Alto: 5
#   Esquina inferior derecha (x, y): (605, 2778)
#
# Objeto 228:
#   Coordenadas esquina superior izquierda (x, y): (547, 2773)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (548, 2774)
#
# Objeto 229:
#   Coordenadas esquina superior izquierda (x, y): (946, 2772)
#   Ancho: 6, Alto: 4
#   Esquina inferior derecha (x, y): (952, 2776)
#
# Objeto 230:
#   Coordenadas esquina superior izquierda (x, y): (878, 2771)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (879, 2772)
#
# Objeto 231:
#   Coordenadas esquina superior izquierda (x, y): (875, 2771)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (877, 2773)
#
# Objeto 232:
#   Coordenadas esquina superior izquierda (x, y): (606, 2771)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (607, 2772)
#
# Objeto 233:
#   Coordenadas esquina superior izquierda (x, y): (528, 2771)
#   Ancho: 2, Alto: 3
#   Esquina inferior derecha (x, y): (530, 2774)
#
# Objeto 234:
#   Coordenadas esquina superior izquierda (x, y): (134, 2770)
#   Ancho: 7, Alto: 2
#   Esquina inferior derecha (x, y): (141, 2772)
#
# Objeto 235:
#   Coordenadas esquina superior izquierda (x, y): (903, 2769)
#   Ancho: 3, Alto: 3
#   Esquina inferior derecha (x, y): (906, 2772)
#
# Objeto 236:
#   Coordenadas esquina superior izquierda (x, y): (927, 2768)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (928, 2769)
#
# Objeto 237:
#   Coordenadas esquina superior izquierda (x, y): (550, 2768)
#   Ancho: 4, Alto: 6
#   Esquina inferior derecha (x, y): (554, 2774)
#
# Objeto 238:
#   Coordenadas esquina superior izquierda (x, y): (612, 2764)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (613, 2765)
#
# Objeto 239:
#   Coordenadas esquina superior izquierda (x, y): (541, 2764)
#   Ancho: 4, Alto: 9
#   Esquina inferior derecha (x, y): (545, 2773)
#
# Objeto 240:
#   Coordenadas esquina superior izquierda (x, y): (928, 2763)
#   Ancho: 5, Alto: 5
#   Esquina inferior derecha (x, y): (933, 2768)
#
# Objeto 241:
#   Coordenadas esquina superior izquierda (x, y): (873, 2763)
#   Ancho: 5, Alto: 7
#   Esquina inferior derecha (x, y): (878, 2770)
#
# Objeto 242:
#   Coordenadas esquina superior izquierda (x, y): (1248, 2761)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1249, 2762)
#
# Objeto 243:
#   Coordenadas esquina superior izquierda (x, y): (615, 2761)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (616, 2762)
#
# Objeto 244:
#   Coordenadas esquina superior izquierda (x, y): (939, 2757)
#   Ancho: 4, Alto: 4
#   Esquina inferior derecha (x, y): (943, 2761)
#
# Objeto 245:
#   Coordenadas esquina superior izquierda (x, y): (925, 2757)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (926, 2758)
#
# Objeto 246:
#   Coordenadas esquina superior izquierda (x, y): (555, 2756)
#   Ancho: 1, Alto: 4
#   Esquina inferior derecha (x, y): (556, 2760)
#
# Objeto 247:
#   Coordenadas esquina superior izquierda (x, y): (539, 2752)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (541, 2754)
#
# Objeto 248:
#   Coordenadas esquina superior izquierda (x, y): (1159, 2751)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1160, 2752)
#
# Objeto 249:
#   Coordenadas esquina superior izquierda (x, y): (943, 2749)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (944, 2750)
#
# Objeto 250:
#   Coordenadas esquina superior izquierda (x, y): (42, 2746)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (43, 2747)
#
# Objeto 251:
#   Coordenadas esquina superior izquierda (x, y): (1202, 2744)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1203, 2745)
#
# Objeto 252:
#   Coordenadas esquina superior izquierda (x, y): (1190, 2744)
#   Ancho: 8, Alto: 9
#   Esquina inferior derecha (x, y): (1198, 2753)
#
# Objeto 253:
#   Coordenadas esquina superior izquierda (x, y): (1171, 2744)
#   Ancho: 3, Alto: 1
#   Esquina inferior derecha (x, y): (1174, 2745)
#
# Objeto 254:
#   Coordenadas esquina superior izquierda (x, y): (1176, 2742)
#   Ancho: 6, Alto: 4
#   Esquina inferior derecha (x, y): (1182, 2746)
#
# Objeto 255:
#   Coordenadas esquina superior izquierda (x, y): (956, 2741)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (957, 2742)
#
# Objeto 256:
#   Coordenadas esquina superior izquierda (x, y): (43, 2741)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (44, 2742)
#
# Objeto 257:
#   Coordenadas esquina superior izquierda (x, y): (1191, 2740)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1192, 2741)
#
# Objeto 258:
#   Coordenadas esquina superior izquierda (x, y): (41, 2738)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (43, 2740)
#
# Objeto 259:
#   Coordenadas esquina superior izquierda (x, y): (521, 2737)
#   Ancho: 10, Alto: 28
#   Esquina inferior derecha (x, y): (531, 2765)
#
# Objeto 260:
#   Coordenadas esquina superior izquierda (x, y): (554, 2735)
#   Ancho: 2, Alto: 17
#   Esquina inferior derecha (x, y): (556, 2752)
#
# Objeto 261:
#   Coordenadas esquina superior izquierda (x, y): (1021, 2733)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (1023, 2735)
#
# Objeto 262:
#   Coordenadas esquina superior izquierda (x, y): (547, 2733)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (548, 2734)
#
# Objeto 263:
#   Coordenadas esquina superior izquierda (x, y): (76, 2733)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (78, 2735)
#
# Objeto 264:
#   Coordenadas esquina superior izquierda (x, y): (37, 2733)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (38, 2734)
#
# Objeto 265:
#   Coordenadas esquina superior izquierda (x, y): (554, 2731)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (555, 2732)
#
# Objeto 266:
#   Coordenadas esquina superior izquierda (x, y): (871, 2730)
#   Ancho: 4, Alto: 18
#   Esquina inferior derecha (x, y): (875, 2748)
#
# Objeto 267:
#   Coordenadas esquina superior izquierda (x, y): (1016, 2728)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1017, 2729)
#
# Objeto 268:
#   Coordenadas esquina superior izquierda (x, y): (650, 2727)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (651, 2728)
#
# Objeto 269:
#   Coordenadas esquina superior izquierda (x, y): (535, 2726)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (536, 2728)
#
# Objeto 270:
#   Coordenadas esquina superior izquierda (x, y): (617, 2725)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (618, 2726)
#
# Objeto 271:
#   Coordenadas esquina superior izquierda (x, y): (544, 2725)
#   Ancho: 8, Alto: 7
#   Esquina inferior derecha (x, y): (552, 2732)
#
# Objeto 272:
#   Coordenadas esquina superior izquierda (x, y): (38, 2725)
#   Ancho: 1, Alto: 3
#   Esquina inferior derecha (x, y): (39, 2728)
#
# Objeto 273:
#   Coordenadas esquina superior izquierda (x, y): (553, 2724)
#   Ancho: 3, Alto: 4
#   Esquina inferior derecha (x, y): (556, 2728)
#
# Objeto 274:
#   Coordenadas esquina superior izquierda (x, y): (31, 2723)
#   Ancho: 4, Alto: 6
#   Esquina inferior derecha (x, y): (35, 2729)
#
# Objeto 275:
#   Coordenadas esquina superior izquierda (x, y): (617, 2721)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (618, 2723)
#
# Objeto 276:
#   Coordenadas esquina superior izquierda (x, y): (553, 2721)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (554, 2722)
#
# Objeto 277:
#   Coordenadas esquina superior izquierda (x, y): (539, 2720)
#   Ancho: 8, Alto: 4
#   Esquina inferior derecha (x, y): (547, 2724)
#
# Objeto 278:
#   Coordenadas esquina superior izquierda (x, y): (72, 2719)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (73, 2720)
#
# Objeto 279:
#   Coordenadas esquina superior izquierda (x, y): (609, 2718)
#   Ancho: 4, Alto: 2
#   Esquina inferior derecha (x, y): (613, 2720)
#
# Objeto 280:
#   Coordenadas esquina superior izquierda (x, y): (521, 2718)
#   Ancho: 6, Alto: 12
#   Esquina inferior derecha (x, y): (527, 2730)
#
# Objeto 281:
#   Coordenadas esquina superior izquierda (x, y): (66, 2718)
#   Ancho: 5, Alto: 3
#   Esquina inferior derecha (x, y): (71, 2721)
#
# Objeto 282:
#   Coordenadas esquina superior izquierda (x, y): (29, 2718)
#   Ancho: 1, Alto: 3
#   Esquina inferior derecha (x, y): (30, 2721)
#
# Objeto 283:
#   Coordenadas esquina superior izquierda (x, y): (535, 2714)
#   Ancho: 3, Alto: 4
#   Esquina inferior derecha (x, y): (538, 2718)
#
# Objeto 284:
#   Coordenadas esquina superior izquierda (x, y): (81, 2713)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (82, 2714)
#
# Objeto 285:
#   Coordenadas esquina superior izquierda (x, y): (536, 2712)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (537, 2713)
#
# Objeto 286:
#   Coordenadas esquina superior izquierda (x, y): (46, 2711)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (48, 2713)
#
# Objeto 287:
#   Coordenadas esquina superior izquierda (x, y): (81, 2710)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (82, 2711)
#
# Objeto 288:
#   Coordenadas esquina superior izquierda (x, y): (553, 2709)
#   Ancho: 3, Alto: 10
#   Esquina inferior derecha (x, y): (556, 2719)
#
# Objeto 289:
#   Coordenadas esquina superior izquierda (x, y): (548, 2709)
#   Ancho: 3, Alto: 3
#   Esquina inferior derecha (x, y): (551, 2712)
#
# Objeto 290:
#   Coordenadas esquina superior izquierda (x, y): (540, 2705)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (542, 2707)
#
# Objeto 291:
#   Coordenadas esquina superior izquierda (x, y): (81, 2705)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (82, 2706)
#
# Objeto 292:
#   Coordenadas esquina superior izquierda (x, y): (551, 2704)
#   Ancho: 4, Alto: 2
#   Esquina inferior derecha (x, y): (555, 2706)
#
# Objeto 293:
#   Coordenadas esquina superior izquierda (x, y): (45, 2704)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (46, 2706)
#
# Objeto 294:
#   Coordenadas esquina superior izquierda (x, y): (78, 2703)
#   Ancho: 1, Alto: 3
#   Esquina inferior derecha (x, y): (79, 2706)
#
# Objeto 295:
#   Coordenadas esquina superior izquierda (x, y): (61, 2702)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (63, 2703)
#
# Objeto 296:
#   Coordenadas esquina superior izquierda (x, y): (46, 2702)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (47, 2703)
#
# Objeto 297:
#   Coordenadas esquina superior izquierda (x, y): (27, 2702)
#   Ancho: 4, Alto: 10
#   Esquina inferior derecha (x, y): (31, 2712)
#
# Objeto 298:
#   Coordenadas esquina superior izquierda (x, y): (554, 2699)
#   Ancho: 2, Alto: 4
#   Esquina inferior derecha (x, y): (556, 2703)
#
# Objeto 299:
#   Coordenadas esquina superior izquierda (x, y): (60, 2699)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (61, 2701)
#
# Objeto 300:
#   Coordenadas esquina superior izquierda (x, y): (659, 2698)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (661, 2699)
#
# Objeto 301:
#   Coordenadas esquina superior izquierda (x, y): (26, 2698)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (27, 2700)
#
# Objeto 302:
#   Coordenadas esquina superior izquierda (x, y): (77, 2697)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (78, 2698)
#
# Objeto 303:
#   Coordenadas esquina superior izquierda (x, y): (46, 2697)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (47, 2699)
#
# Objeto 304:
#   Coordenadas esquina superior izquierda (x, y): (859, 2696)
#   Ancho: 4, Alto: 9
#   Esquina inferior derecha (x, y): (863, 2705)
#
# Objeto 305:
#   Coordenadas esquina superior izquierda (x, y): (44, 2696)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (45, 2697)
#
# Objeto 306:
#   Coordenadas esquina superior izquierda (x, y): (27, 2696)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (28, 2697)
#
# Objeto 307:
#   Coordenadas esquina superior izquierda (x, y): (542, 2694)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (543, 2695)
#
# Objeto 308:
#   Coordenadas esquina superior izquierda (x, y): (531, 2694)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (532, 2695)
#
# Objeto 309:
#   Coordenadas esquina superior izquierda (x, y): (128, 2694)
#   Ancho: 14, Alto: 2
#   Esquina inferior derecha (x, y): (142, 2696)
#
# Objeto 310:
#   Coordenadas esquina superior izquierda (x, y): (50, 2694)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (51, 2695)
#
# Objeto 311:
#   Coordenadas esquina superior izquierda (x, y): (522, 2693)
#   Ancho: 2, Alto: 3
#   Esquina inferior derecha (x, y): (524, 2696)
#
# Objeto 312:
#   Coordenadas esquina superior izquierda (x, y): (554, 2692)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (556, 2694)
#
# Objeto 313:
#   Coordenadas esquina superior izquierda (x, y): (538, 2692)
#   Ancho: 3, Alto: 5
#   Esquina inferior derecha (x, y): (541, 2697)
#
# Objeto 314:
#   Coordenadas esquina superior izquierda (x, y): (863, 2691)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (864, 2693)
#
# Objeto 315:
#   Coordenadas esquina superior izquierda (x, y): (329, 2691)
#   Ancho: 3, Alto: 2
#   Esquina inferior derecha (x, y): (332, 2693)
#
# Objeto 316:
#   Coordenadas esquina superior izquierda (x, y): (81, 2690)
#   Ancho: 1, Alto: 14
#   Esquina inferior derecha (x, y): (82, 2704)
#
# Objeto 317:
#   Coordenadas esquina superior izquierda (x, y): (863, 2689)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (864, 2690)
#
# Objeto 318:
#   Coordenadas esquina superior izquierda (x, y): (555, 2689)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (556, 2690)
#
# Objeto 319:
#   Coordenadas esquina superior izquierda (x, y): (332, 2689)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (333, 2690)
#
# Objeto 320:
#   Coordenadas esquina superior izquierda (x, y): (326, 2689)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (327, 2690)
#
# Objeto 321:
#   Coordenadas esquina superior izquierda (x, y): (62, 2689)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (63, 2690)
#
# Objeto 322:
#   Coordenadas esquina superior izquierda (x, y): (860, 2688)
#   Ancho: 2, Alto: 5
#   Esquina inferior derecha (x, y): (862, 2693)
#
# Objeto 323:
#   Coordenadas esquina superior izquierda (x, y): (287, 2688)
#   Ancho: 3, Alto: 3
#   Esquina inferior derecha (x, y): (290, 2691)
#
# Objeto 324:
#   Coordenadas esquina superior izquierda (x, y): (283, 2688)
#   Ancho: 3, Alto: 4
#   Esquina inferior derecha (x, y): (286, 2692)
#
# Objeto 325:
#   Coordenadas esquina superior izquierda (x, y): (80, 2688)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (82, 2689)
#
# Objeto 326:
#   Coordenadas esquina superior izquierda (x, y): (554, 2687)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (555, 2688)
#
# Objeto 327:
#   Coordenadas esquina superior izquierda (x, y): (38, 2686)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (39, 2687)
#
# Objeto 328:
#   Coordenadas esquina superior izquierda (x, y): (546, 2685)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (547, 2686)
#
# Objeto 329:
#   Coordenadas esquina superior izquierda (x, y): (537, 2685)
#   Ancho: 3, Alto: 4
#   Esquina inferior derecha (x, y): (540, 2689)
#
# Objeto 330:
#   Coordenadas esquina superior izquierda (x, y): (863, 2683)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (864, 2684)
#
# Objeto 331:
#   Coordenadas esquina superior izquierda (x, y): (857, 2683)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (858, 2684)
#
# Objeto 332:
#   Coordenadas esquina superior izquierda (x, y): (67, 2683)
#   Ancho: 1, Alto: 3
#   Esquina inferior derecha (x, y): (68, 2686)
#
# Objeto 333:
#   Coordenadas esquina superior izquierda (x, y): (539, 2682)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (540, 2683)
#
# Objeto 334:
#   Coordenadas esquina superior izquierda (x, y): (80, 2682)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (81, 2683)
#
# Objeto 335:
#   Coordenadas esquina superior izquierda (x, y): (554, 2681)
#   Ancho: 1, Alto: 4
#   Esquina inferior derecha (x, y): (555, 2685)
#
# Objeto 336:
#   Coordenadas esquina superior izquierda (x, y): (45, 2681)
#   Ancho: 2, Alto: 3
#   Esquina inferior derecha (x, y): (47, 2684)
#
# Objeto 337:
#   Coordenadas esquina superior izquierda (x, y): (61, 2680)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (62, 2682)
#
# Objeto 338:
#   Coordenadas esquina superior izquierda (x, y): (45, 2679)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (46, 2680)
#
# Objeto 339:
#   Coordenadas esquina superior izquierda (x, y): (50, 2676)
#   Ancho: 2, Alto: 4
#   Esquina inferior derecha (x, y): (52, 2680)
#
# Objeto 340:
#   Coordenadas esquina superior izquierda (x, y): (63, 2675)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (64, 2676)
#
# Objeto 341:
#   Coordenadas esquina superior izquierda (x, y): (45, 2675)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (46, 2677)
#
# Objeto 342:
#   Coordenadas esquina superior izquierda (x, y): (128, 2674)
# ...
#   Ancho: 2, Alto: 4
#   Esquina inferior derecha (x, y): (695, 79)
#
# Objeto 4658:
#   Coordenadas esquina superior izquierda (x, y): (557, 75)
#   Ancho: 2, Alto: 5
#   Esquina inferior derecha (x, y): (559, 80)
#
# Objeto 4659:
#   Coordenadas esquina superior izquierda (x, y): (1394, 74)
#   Ancho: 5, Alto: 6
#   Esquina inferior derecha (x, y): (1399, 80)
#
# Objeto 4660:
#   Coordenadas esquina superior izquierda (x, y): (1334, 74)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (1335, 76)
#
# Objeto 4661:
#   Coordenadas esquina superior izquierda (x, y): (1013, 74)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (1014, 76)
#
# Objeto 4662:
#   Coordenadas esquina superior izquierda (x, y): (696, 74)
#   Ancho: 25, Alto: 20
#   Esquina inferior derecha (x, y): (721, 94)
#
# Objeto 4663:
#   Coordenadas esquina superior izquierda (x, y): (1329, 73)
#   Ancho: 14, Alto: 16
#   Esquina inferior derecha (x, y): (1343, 89)
#
# Objeto 4664:
#   Coordenadas esquina superior izquierda (x, y): (1328, 72)
#   Ancho: 5, Alto: 8
#   Esquina inferior derecha (x, y): (1333, 80)
#
# Objeto 4665:
#   Coordenadas esquina superior izquierda (x, y): (556, 72)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (557, 73)
#
# Objeto 4666:
#   Coordenadas esquina superior izquierda (x, y): (1398, 71)
#   Ancho: 10, Alto: 10
#   Esquina inferior derecha (x, y): (1408, 81)
#
# Objeto 4667:
#   Coordenadas esquina superior izquierda (x, y): (549, 71)
#   Ancho: 3, Alto: 5
#   Esquina inferior derecha (x, y): (552, 76)
#
# Objeto 4668:
#   Coordenadas esquina superior izquierda (x, y): (951, 70)
#   Ancho: 1, Alto: 4
#   Esquina inferior derecha (x, y): (952, 74)
#
# Objeto 4669:
#   Coordenadas esquina superior izquierda (x, y): (810, 70)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (811, 72)
#
# Objeto 4670:
#   Coordenadas esquina superior izquierda (x, y): (1377, 68)
#   Ancho: 4, Alto: 4
#   Esquina inferior derecha (x, y): (1381, 72)
#
# Objeto 4671:
#   Coordenadas esquina superior izquierda (x, y): (557, 68)
#   Ancho: 3, Alto: 6
#   Esquina inferior derecha (x, y): (560, 74)
#
# Objeto 4672:
#   Coordenadas esquina superior izquierda (x, y): (554, 68)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (556, 70)
#
# Objeto 4673:
#   Coordenadas esquina superior izquierda (x, y): (1280, 67)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1281, 68)
#
# Objeto 4674:
#   Coordenadas esquina superior izquierda (x, y): (967, 66)
#   Ancho: 2, Alto: 6
#   Esquina inferior derecha (x, y): (969, 72)
#
# Objeto 4675:
#   Coordenadas esquina superior izquierda (x, y): (949, 66)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (950, 67)
#
# Objeto 4676:
#   Coordenadas esquina superior izquierda (x, y): (548, 66)
#   Ancho: 3, Alto: 2
#   Esquina inferior derecha (x, y): (551, 68)
#
# Objeto 4677:
#   Coordenadas esquina superior izquierda (x, y): (1366, 65)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (1368, 67)
#
# Objeto 4678:
#   Coordenadas esquina superior izquierda (x, y): (1359, 65)
#   Ancho: 6, Alto: 6
#   Esquina inferior derecha (x, y): (1365, 71)
#
# Objeto 4679:
#   Coordenadas esquina superior izquierda (x, y): (1142, 65)
#   Ancho: 2, Alto: 3
#   Esquina inferior derecha (x, y): (1144, 68)
#
# Objeto 4680:
#   Coordenadas esquina superior izquierda (x, y): (808, 65)
#   Ancho: 3, Alto: 3
#   Esquina inferior derecha (x, y): (811, 68)
#
# Objeto 4681:
#   Coordenadas esquina superior izquierda (x, y): (1364, 64)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1365, 65)
#
# Objeto 4682:
#   Coordenadas esquina superior izquierda (x, y): (1357, 64)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1358, 65)
#
# Objeto 4683:
#   Coordenadas esquina superior izquierda (x, y): (1282, 64)
#   Ancho: 8, Alto: 11
#   Esquina inferior derecha (x, y): (1290, 75)
#
# Objeto 4684:
#   Coordenadas esquina superior izquierda (x, y): (977, 63)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (978, 64)
#
# Objeto 4685:
#   Coordenadas esquina superior izquierda (x, y): (1313, 62)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1314, 63)
#
# Objeto 4686:
#   Coordenadas esquina superior izquierda (x, y): (970, 62)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (971, 63)
#
# Objeto 4687:
#   Coordenadas esquina superior izquierda (x, y): (545, 62)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (547, 64)
#
# Objeto 4688:
#   Coordenadas esquina superior izquierda (x, y): (1374, 60)
#   Ancho: 2, Alto: 4
#   Esquina inferior derecha (x, y): (1376, 64)
#
# Objeto 4689:
#   Coordenadas esquina superior izquierda (x, y): (1325, 60)
#   Ancho: 9, Alto: 7
#   Esquina inferior derecha (x, y): (1334, 67)
#
# Objeto 4690:
#   Coordenadas esquina superior izquierda (x, y): (699, 60)
#   Ancho: 6, Alto: 8
#   Esquina inferior derecha (x, y): (705, 68)
#
# Objeto 4691:
#   Coordenadas esquina superior izquierda (x, y): (1317, 59)
#   Ancho: 5, Alto: 9
#   Esquina inferior derecha (x, y): (1322, 68)
#
# Objeto 4692:
#   Coordenadas esquina superior izquierda (x, y): (1305, 59)
#   Ancho: 7, Alto: 3
#   Esquina inferior derecha (x, y): (1312, 62)
#
# Objeto 4693:
#   Coordenadas esquina superior izquierda (x, y): (1298, 59)
#   Ancho: 4, Alto: 3
#   Esquina inferior derecha (x, y): (1302, 62)
#
# Objeto 4694:
#   Coordenadas esquina superior izquierda (x, y): (1416, 58)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1417, 59)
#
# Objeto 4695:
#   Coordenadas esquina superior izquierda (x, y): (1280, 58)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (1281, 60)
#
# Objeto 4696:
#   Coordenadas esquina superior izquierda (x, y): (1389, 57)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (1391, 58)
#
# Objeto 4697:
#   Coordenadas esquina superior izquierda (x, y): (1348, 56)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (1349, 58)
#
# Objeto 4698:
#   Coordenadas esquina superior izquierda (x, y): (1161, 56)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (1163, 57)
#
# Objeto 4699:
#   Coordenadas esquina superior izquierda (x, y): (1016, 56)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (1017, 58)
#
# Objeto 4700:
#   Coordenadas esquina superior izquierda (x, y): (999, 56)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1000, 57)
#
# Objeto 4701:
#   Coordenadas esquina superior izquierda (x, y): (879, 56)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (880, 58)
#
# Objeto 4702:
#   Coordenadas esquina superior izquierda (x, y): (1387, 55)
#   Ancho: 24, Alto: 11
#   Esquina inferior derecha (x, y): (1411, 66)
#
# Objeto 4703:
#   Coordenadas esquina superior izquierda (x, y): (1345, 54)
#   Ancho: 2, Alto: 4
#   Esquina inferior derecha (x, y): (1347, 58)
#
# Objeto 4704:
#   Coordenadas esquina superior izquierda (x, y): (1017, 54)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1018, 55)
#
# Objeto 4705:
#   Coordenadas esquina superior izquierda (x, y): (1101, 53)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (1103, 55)
#
# Objeto 4706:
#   Coordenadas esquina superior izquierda (x, y): (1354, 50)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (1356, 52)
#
# Objeto 4707:
#   Coordenadas esquina superior izquierda (x, y): (1362, 49)
#   Ancho: 7, Alto: 14
#   Esquina inferior derecha (x, y): (1369, 63)
#
# Objeto 4708:
#   Coordenadas esquina superior izquierda (x, y): (974, 49)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (975, 50)
#
# Objeto 4709:
#   Coordenadas esquina superior izquierda (x, y): (1104, 48)
#   Ancho: 5, Alto: 6
#   Esquina inferior derecha (x, y): (1109, 54)
#
# Objeto 4710:
#   Coordenadas esquina superior izquierda (x, y): (1117, 47)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1118, 48)
#
# Objeto 4711:
#   Coordenadas esquina superior izquierda (x, y): (1044, 47)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (1046, 48)
#
# Objeto 4712:
#   Coordenadas esquina superior izquierda (x, y): (1020, 46)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1021, 47)
#
# Objeto 4713:
#   Coordenadas esquina superior izquierda (x, y): (1003, 46)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1004, 47)
#
# Objeto 4714:
#   Coordenadas esquina superior izquierda (x, y): (171, 46)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (172, 47)
#
# Objeto 4715:
#   Coordenadas esquina superior izquierda (x, y): (1001, 45)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (1002, 47)
#
# Objeto 4716:
#   Coordenadas esquina superior izquierda (x, y): (1021, 43)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1022, 44)
#
# Objeto 4717:
#   Coordenadas esquina superior izquierda (x, y): (1126, 42)
#   Ancho: 8, Alto: 6
#   Esquina inferior derecha (x, y): (1134, 48)
#
# Objeto 4718:
#   Coordenadas esquina superior izquierda (x, y): (979, 42)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (980, 44)
#
# Objeto 4719:
#   Coordenadas esquina superior izquierda (x, y): (1159, 41)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1160, 42)
#
# Objeto 4720:
#   Coordenadas esquina superior izquierda (x, y): (1128, 40)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1129, 41)
#
# Objeto 4721:
#   Coordenadas esquina superior izquierda (x, y): (982, 40)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (983, 42)
#
# Objeto 4722:
#   Coordenadas esquina superior izquierda (x, y): (959, 38)
#   Ancho: 22, Alto: 23
#   Esquina inferior derecha (x, y): (981, 61)
#
# Objeto 4723:
#   Coordenadas esquina superior izquierda (x, y): (66, 38)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (67, 39)
#
# Objeto 4724:
#   Coordenadas esquina superior izquierda (x, y): (1024, 35)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1025, 36)
#
# Objeto 4725:
#   Coordenadas esquina superior izquierda (x, y): (1146, 34)
#   Ancho: 13, Alto: 15
#   Esquina inferior derecha (x, y): (1159, 49)
#
# Objeto 4726:
#   Coordenadas esquina superior izquierda (x, y): (1090, 32)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (1092, 33)
#
# Objeto 4727:
#   Coordenadas esquina superior izquierda (x, y): (979, 32)
#   Ancho: 3, Alto: 4
#   Esquina inferior derecha (x, y): (982, 36)
#
# Objeto 4728:
#   Coordenadas esquina superior izquierda (x, y): (1101, 31)
#   Ancho: 4, Alto: 6
#   Esquina inferior derecha (x, y): (1105, 37)
#
# Objeto 4729:
#   Coordenadas esquina superior izquierda (x, y): (1121, 30)
#   Ancho: 4, Alto: 6
#   Esquina inferior derecha (x, y): (1125, 36)
#
# Objeto 4730:
#   Coordenadas esquina superior izquierda (x, y): (1090, 29)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1091, 30)
#
# Objeto 4731:
#   Coordenadas esquina superior izquierda (x, y): (1025, 29)
#   Ancho: 3, Alto: 4
#   Esquina inferior derecha (x, y): (1028, 33)
#
# Objeto 4732:
#   Coordenadas esquina superior izquierda (x, y): (791, 28)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (792, 29)
#
# Objeto 4733:
#   Coordenadas esquina superior izquierda (x, y): (1130, 27)
#   Ancho: 10, Alto: 13
#   Esquina inferior derecha (x, y): (1140, 40)
#
# Objeto 4734:
#   Coordenadas esquina superior izquierda (x, y): (1102, 26)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (1103, 28)
#
# Objeto 4735:
#   Coordenadas esquina superior izquierda (x, y): (1008, 26)
#   Ancho: 4, Alto: 7
#   Esquina inferior derecha (x, y): (1012, 33)
#
# Objeto 4736:
#   Coordenadas esquina superior izquierda (x, y): (1369, 25)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1370, 26)
#
# Objeto 4737:
#   Coordenadas esquina superior izquierda (x, y): (1095, 25)
#   Ancho: 5, Alto: 7
#   Esquina inferior derecha (x, y): (1100, 32)
#
# Objeto 4738:
#   Coordenadas esquina superior izquierda (x, y): (1368, 23)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1369, 24)
#
# Objeto 4739:
#   Coordenadas esquina superior izquierda (x, y): (1358, 22)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (1359, 24)
#
# Objeto 4740:
#   Coordenadas esquina superior izquierda (x, y): (1102, 22)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1103, 23)
#
# Objeto 4741:
#   Coordenadas esquina superior izquierda (x, y): (1031, 22)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1032, 23)
#
# Objeto 4742:
#   Coordenadas esquina superior izquierda (x, y): (1089, 20)
#   Ancho: 3, Alto: 5
#   Esquina inferior derecha (x, y): (1092, 25)
#
# Objeto 4743:
#   Coordenadas esquina superior izquierda (x, y): (761, 20)
#   Ancho: 47, Alto: 16
#   Esquina inferior derecha (x, y): (808, 36)
#
# Objeto 4744:
#   Coordenadas esquina superior izquierda (x, y): (757, 20)
#   Ancho: 3, Alto: 1
#   Esquina inferior derecha (x, y): (760, 21)
#
# Objeto 4745:
#   Coordenadas esquina superior izquierda (x, y): (1358, 19)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (1360, 20)
#
# Objeto 4746:
#   Coordenadas esquina superior izquierda (x, y): (1132, 16)
#   Ancho: 3, Alto: 1
#   Esquina inferior derecha (x, y): (1135, 17)
#
# Objeto 4747:
#   Coordenadas esquina superior izquierda (x, y): (1096, 16)
#   Ancho: 1, Alto: 3
#   Esquina inferior derecha (x, y): (1097, 19)
#
# Objeto 4748:
#   Coordenadas esquina superior izquierda (x, y): (978, 16)
#   Ancho: 1, Alto: 3
#   Esquina inferior derecha (x, y): (979, 19)
#
# Objeto 4749:
#   Coordenadas esquina superior izquierda (x, y): (949, 15)
#   Ancho: 12, Alto: 21
#   Esquina inferior derecha (x, y): (961, 36)
#
# Objeto 4750:
#   Coordenadas esquina superior izquierda (x, y): (742, 15)
#   Ancho: 5, Alto: 4
#   Esquina inferior derecha (x, y): (747, 19)
#
# Objeto 4751:
#   Coordenadas esquina superior izquierda (x, y): (983, 13)
#   Ancho: 1, Alto: 3
#   Esquina inferior derecha (x, y): (984, 16)
#
# Objeto 4752:
#   Coordenadas esquina superior izquierda (x, y): (960, 13)
#   Ancho: 3, Alto: 3
#   Esquina inferior derecha (x, y): (963, 16)
#
# Objeto 4753:
#   Coordenadas esquina superior izquierda (x, y): (736, 12)
#   Ancho: 2, Alto: 3
#   Esquina inferior derecha (x, y): (738, 15)
#
# Objeto 4754:
#   Coordenadas esquina superior izquierda (x, y): (730, 12)
#   Ancho: 3, Alto: 2
#   Esquina inferior derecha (x, y): (733, 14)
#
# Objeto 4755:
#   Coordenadas esquina superior izquierda (x, y): (1045, 11)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1046, 12)
#
# Objeto 4756:
#   Coordenadas esquina superior izquierda (x, y): (997, 10)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (998, 11)
#
# Objeto 4757:
#   Coordenadas esquina superior izquierda (x, y): (983, 10)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (984, 12)
#
# Objeto 4758:
#   Coordenadas esquina superior izquierda (x, y): (1163, 8)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1164, 9)
#
# Objeto 4759:
#   Coordenadas esquina superior izquierda (x, y): (1109, 8)
#   Ancho: 4, Alto: 4
#   Esquina inferior derecha (x, y): (1113, 12)
#
# Objeto 4760:
#   Coordenadas esquina superior izquierda (x, y): (1099, 6)
#   Ancho: 2, Alto: 1
#   Esquina inferior derecha (x, y): (1101, 7)
#
# Objeto 4761:
#   Coordenadas esquina superior izquierda (x, y): (1050, 6)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (1052, 8)
#
# Objeto 4762:
#   Coordenadas esquina superior izquierda (x, y): (1166, 5)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1167, 6)
#
# Objeto 4763:
#   Coordenadas esquina superior izquierda (x, y): (1053, 4)
#   Ancho: 3, Alto: 2
#   Esquina inferior derecha (x, y): (1056, 6)
#
# Objeto 4764:
#   Coordenadas esquina superior izquierda (x, y): (973, 2)
#   Ancho: 10, Alto: 7
#   Esquina inferior derecha (x, y): (983, 9)
#
# Objeto 4765:
#   Coordenadas esquina superior izquierda (x, y): (968, 2)
#   Ancho: 2, Alto: 2
#   Esquina inferior derecha (x, y): (970, 4)
#
# Objeto 4766:
#   Coordenadas esquina superior izquierda (x, y): (1349, 0)
#   Ancho: 1, Alto: 1
#   Esquina inferior derecha (x, y): (1350, 1)
#
# Objeto 4767:
#   Coordenadas esquina superior izquierda (x, y): (1120, 0)
#   Ancho: 32, Alto: 20
#   Esquina inferior derecha (x, y): (1152, 20)
#
# Objeto 4768:
#   Coordenadas esquina superior izquierda (x, y): (1011, 0)
#   Ancho: 35, Alto: 25
#   Esquina inferior derecha (x, y): (1046, 25)
#
# Objeto 4769:
#   Coordenadas esquina superior izquierda (x, y): (949, 0)
#   Ancho: 14, Alto: 12
#   Esquina inferior derecha (x, y): (963, 12)
#
# Objeto 4770:
#   Coordenadas esquina superior izquierda (x, y): (937, 0)
#   Ancho: 9, Alto: 15
#   Esquina inferior derecha (x, y): (946, 15)
#
# Objeto 4771:
#   Coordenadas esquina superior izquierda (x, y): (927, 0)
#   Ancho: 1, Alto: 2
#   Esquina inferior derecha (x, y): (928, 2)

# %%
# Mostrar la imagen con los rectángulos
plt.figure(figsize=(8, 6))
plt.imshow(imagen_rect)
plt.title('Objetos Rojos con Rectángulos')
plt.axis('off')
plt.show()

# %%
# Encontrar contornos
contornos, _ = cv2.findContours(mascara_roja, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Copiar imagen original para dibujar rectángulos
imagen_rect = imagen_rgb.copy()

# Dibujar rectángulo en cada contorno encontrado
for contorno in contornos:
    x, y, w, h = cv2.boundingRect(contorno)
    cv2.rectangle(imagen_rect, (x, y), (x + w, y + h), (0, 255, 0), 2)

# Mostrar resultados
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(imagen_rgb)
plt.title('Imagen Original')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(cv2.bitwise_and(imagen_rgb, imagen_rgb, mask=mascara_roja))
plt.title('Segmentación en Color')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(imagen_rect)
plt.title('Rectángulos sobre objetos rojos')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
cv2.putText(imagen_rgb, "Multiverso de Spiderman",
            (150, 160),  # ← Bajamos la posición en Y (de 120 a 160)
            cv2.FONT_HERSHEY_SIMPLEX,
            4.5,          # Escala grande
            (255, 255, 255),  # Color blanco
            8)

plt.imshow(imagen_rgb)
plt.axis('on')
plt.show()

# %% [markdown]
# ##6. Presentaciones preliminares
#
# Cada uno/una de ustedes va a tener 5 minutos para mostrarnos su trabajo, que debe incluir:
#
# La imagen original.
#
# La imagen mejorada (ya sea con ajuste de brillo/contraste o ecualización de histograma).
#
# La imagen segmentada.
#
# Una explicación de todo el proceso, incluyendo:
#
# La imagen que eligieron y por qué.
#
# Los valores que usaron para ajustar el brillo y el contraste (si lo hicieron).
#
# El rango de color HSV que eligieron para segmentar y por qué.
#
# Cualquier dificultad que hayan tenido y cómo la resolvieron.

# %% [markdown]
# ## Recursos
#
# ### Datasets Generales:
#
# **[COCO](https://cocodataset.org/) (Common Objects in Context):** Este dataset es muy completo, con imágenes de objetos cotidianos en escenas complejas. Es ideal para practicar segmentación y reconocimiento de objetos.
#
# **Ideas para el proyecto:** Segmentar diferentes objetos en una escena (personas, autos, animales) y analizar sus relaciones espaciales.
#
#
# **[Open Images](https://storage.googleapis.com/openimages/web/index.html):** Un dataset masivo con millones de imágenes y anotaciones de objetos. Ofrece una gran variedad de temas y es excelente para proyectos más ambiciosos.
#
# **Ideas para el proyecto:** Detectar y segmentar múltiples objetos en una imagen, o incluso intentar segmentar objetos dentro de un contexto específico (por ejemplo, segmentar diferentes tipos de árboles en un paisaje).
#
#
# **[ImageNet](https://www.image-net.org/):** Este dataset contiene una gran cantidad de imágenes organizadas según la jerarquía de WordNet.
#
# **Ideas para el Proyecto:** Los estudiantes pueden usar un subconjunto de ImageNet para segmentar y clasificar diferentes categorías de imágenes, como animales, vehículos o plantas.
#
#
# ### Datasets Específicos:
#
# **[Flores](https://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html):** Datasets como Oxford Flowers 102 son perfectos para proyectos de segmentación por color, donde los estudiantes pueden aislar flores de diferentes tipos y colores.
#
# **Ideas para el proyecto:** Segmentar flores de un color específico y luego usar técnicas de procesamiento de imágenes para analizar su forma o textura.
#
#
# **[Rostros](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html):** Datasets como CelebA pueden usarse para proyectos de segmentación de características faciales o reconocimiento de rostros.
#
# **Ideas para el proyecto:** Segmentar diferentes partes del rostro (ojos, nariz, boca) y analizar cómo cambian con las expresiones faciales.
#
#
# **[Paisajes Urbanos](https://www.cityscapes-dataset.com/):** Cityscapes es ideal para segmentar elementos en entornos urbanos, como autos, peatones y edificios.
#
# ### Dónde Encontrar Más Datasets:
#
# **[Kaggle](https://www.kaggle.com/datasets?search=image):** Esta plataforma ofrece una gran variedad de datasets de imágenes subidos por la comunidad, que pueden ser útiles para proyectos específicos.
#
#
# **[Papers With Code](https://paperswithcode.com/datasets?mod=images):** Este sitio web recopila datasets utilizados en investigaciones de aprendizaje automático, incluyendo muchos datasets de imágenes.
# Usa el código con precaución
